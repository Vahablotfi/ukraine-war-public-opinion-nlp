# %% [markdown]
# # 04 — Topic Labeling
#
# In the previous notebook, I used LDA topic modeling to generate 5 topics per event.
# This notebook adds **human-readable labels** to those topics so they can be used in:
#
# - the report (clear interpretation)
# - visualizations (plots that people understand)
# - the Streamlit dashboard (dropdown labels)

# %%
import os
import pandas as pd

topic_dir = "../data/processed/topics"

event_files = {
    "event1_kyiv": "event1_kyiv_topics.csv",
    "event2_kherson": "event2_kherson_topics.csv",
    "event3_stalemate": "event3_stalemate_topics.csv",
    "event4_trump_election": "event4_trump_election_topics.csv",
    "event5_white_house_meeting": "event5_white_house_meeting_topics.csv",
}

# %%
topics = {}

for event, fname in event_files.items():
    path = os.path.join(topic_dir, fname)
    df = pd.read_csv(path)
    topics[event] = df

    print(event, "loaded:", df.shape)
# Out:
# event1_kyiv loaded: (5, 2)
# event2_kherson loaded: (5, 2)
# event3_stalemate loaded: (5, 2)
# event4_trump_election loaded: (5, 2)
# event5_white_house_meeting loaded: (5, 2)

# %% [markdown]
# ## Labeling Method
#
# Topic labels were assigned manually based on:
#
# - the top words produced by the model
# - the event context
# - recurring themes across events
#
# The goal is **interpretability**, not perfect automation.

# %%
labels = {
    "event1_kyiv": {
        0: "Battlefield updates (weapons, troops, visuals)",
        1: "Propaganda + moral outrage / reactions",
        2: "Poland border + visas + refugee movement",
        3: "Power balance + escalation talk",
        4: "Invasion framing + military response",
    },
    "event2_kherson": {
        0: "Leadership + war framing (Putin / narratives)",
        1: "War timeline + personal reactions",
        2: "Military shock + civilian harm",
        3: "Help / logistics / questions",
        4: "General reactions + humor / chatter",
    },
    "event3_stalemate": {
        0: "Wagner / coup / power struggle",
        1: "War costs + money + volunteering / work",
        2: "Combat + fighting (frontline talk)",
        3: "Reactions to footage + hot takes",
        4: "Forces + tanks + troop movement",
    },
    "event4_trump_election": {
        0: "News cycle + media framing",
        1: "Memes / anger / online banter",
        2: "Weapons + battlefield tech (tanks/missiles/air)",
        3: "War fatigue / endgame talk",
        4: "Geopolitics (China/North Korea/Europe/support)",
    },
    "event5_white_house_meeting": {
        0: "U.S. elections + partisan/media framing",
        1: "Big-picture opinions + world powers (incl. China)",
        2: "Troops + casualties + war duration",
        3: "Zelensky/president meeting drama reactions",
        4: "Peace deal + Europe + Trump/Putin diplomacy framing",
    },
}

# %%
for event, df in topics.items():
    df = df.copy()
    df["label"] = df["topic_id"].map(labels[event])
    topics[event] = df

    print("\n===", event, "===")
    display(df)
# Out:
# === event1_kyiv ===
#    topic_id                                          top_words  \
# 0         0  used, use, weapons, children, look, troops, se...
# 1         1  shit, did, fuck, way, propaganda, world, right...
# 2         2  pl, visa, ua, news, ready, help, polish, borde...
# 3         3  sure, power, doing, better, mean, bad, point, ...
# 4         4  invasion, yes, countries, did, military, putin...
#
#                                             label
# 0  Battlefield updates (weapons, troops, visuals)
# 1          Propaganda + moral outrage / reactions
# 2        Poland border + visas + refugee movement
# 3                 Power balance + escalation talk
# 4            Invasion framing + military response
# === event2_kherson ===
#    topic_id                                          top_words  \
# 0         0  way, shit, training, country, real, putin, lov...
# 1         1  months, person, fucking, case, great, getting,...
# 2         2  fuck, military, eject, insane, children, belie...
# 3         3  doing, questions, sure, want, line, use, help,...
# 4         4  old, big, thanks, got, ve, sure, work, lol, gu...
#
#                                            label
# 0  Leadership + war framing (Putin / narratives)
# 1              War timeline + personal reactions
# 2                 Military shock + civilian harm
# 3                   Help / logistics / questions
# 4            General reactions + humor / chatter
# === event3_stalemate ===
#    topic_id                                          top_words  \
# 0         0  mod, military, deal, way, coup, wagner, power,...
# 1         1  money, experience, war, work, ukrainian, milit...
# 2         2  video, yeah, fight, did, ukrainian, russians, ...
# 3         3  guys, sure, thing, video, got, shit, right, ru...
# 4         4  force, tank, forces, probably, army, troops, m...
#
#                                      label
# 0           Wagner / coup / power struggle
# 1  War costs + money + volunteering / work
# 2       Combat + fighting (frontline talk)
# 3         Reactions to footage + hot takes
# 4          Forces + tanks + troop movement
# === event4_trump_election ===
#    topic_id                                          top_words  \
# 0         0  need, news, lot, new, year, years, time, media...
# 1         1  thing, fucking, got, time, fuck, guy, shit, ri...
# 2         2  used, tanks, soldiers, hit, air, use, missiles...
# 3         3  years, way, ukrainian, ukrainians, putin, want...
# 4         4  china, support, weapons, military, north, euro...
#
#                                              label
# 0                       News cycle + media framing
# 1                    Memes / anger / online banter
# 2  Weapons + battlefield tech (tanks/missiles/air)
# 3                       War fatigue / endgame talk
# 4   Geopolitics (China/North Korea/Europe/support)
# === event5_white_house_meeting ===
#    topic_id                                          top_words  \
# 0         0  pro, election, american, media, elections, par...
# 1         1  ll, want, maybe, right, shit, make, good, chin...
# 2         2  soldiers, army, year, russians, time, years, g...
# 3         3  right, fuck, good, president, time, zelensky, ...
# 4         4  european, putin, countries, deal, peace, trump...
#
#                                                label
# 0            U.S. elections + partisan/media framing
# 1  Big-picture opinions + world powers (incl. China)
# 2                 Troops + casualties + war duration
# 3         Zelensky/president meeting drama reactions
# 4  Peace deal + Europe + Trump/Putin diplomacy fr...

# %% [markdown]
# ## Notes on Interpretation
#
# Some events have cleaner topics than others.
#
# For example, Event 2 (Kherson) has fewer comments than Events 4–5, so topics can look more general.
# This is expected in real-world NLP and will be mentioned as a limitation in the report.

# %%
out_dir = "../data/processed/topics_labeled"
os.makedirs(out_dir, exist_ok=True)

all_labeled = []

for event, df in topics.items():
    out_path = os.path.join(out_dir, f"{event}_topics_labeled.csv")
    df.to_csv(out_path, index=False)
    print("Saved:", out_path)

    df2 = df.copy()
    df2["event"] = event
    all_labeled.append(df2)

master = pd.concat(all_labeled, ignore_index=True)
master_path = os.path.join(out_dir, "topics_labeled_master.csv")
master.to_csv(master_path, index=False)
print("Saved:", master_path)

master
# Out:
# Saved: ../data/processed/topics_labeled/event1_kyiv_topics_labeled.csv
# Saved: ../data/processed/topics_labeled/event2_kherson_topics_labeled.csv
# Saved: ../data/processed/topics_labeled/event3_stalemate_topics_labeled.csv
# Saved: ../data/processed/topics_labeled/event4_trump_election_topics_labeled.csv
# Saved: ../data/processed/topics_labeled/event5_white_house_meeting_topics_labeled.csv
# Saved: ../data/processed/topics_labeled/topics_labeled_master.csv
#     topic_id                                          top_words  \
# 0          0  used, use, weapons, children, look, troops, se...
# 1          1  shit, did, fuck, way, propaganda, world, right...
# 2          2  pl, visa, ua, news, ready, help, polish, borde...
# 3          3  sure, power, doing, better, mean, bad, point, ...
# 4          4  invasion, yes, countries, did, military, putin...
# 5          0  way, shit, training, country, real, putin, lov...
# 6          1  months, person, fucking, case, great, getting,...
# 7          2  fuck, military, eject, insane, children, belie...
# 8          3  doing, questions, sure, want, line, use, help,...
# 9          4  old, big, thanks, got, ve, sure, work, lol, gu...
# 10         0  mod, military, deal, way, coup, wagner, power,...
# 11         1  money, experience, war, work, ukrainian, milit...
# 12         2  video, yeah, fight, did, ukrainian, russians, ...
# 13         3  guys, sure, thing, video, got, shit, right, ru...
# 14         4  force, tank, forces, probably, army, troops, m...
# 15         0  need, news, lot, new, year, years, time, media...
# 16         1  thing, fucking, got, time, fuck, guy, shit, ri...
# 17         2  used, tanks, soldiers, hit, air, use, missiles...
# 18         3  years, way, ukrainian, ukrainians, putin, want...
# 19         4  china, support, weapons, military, north, euro...
# 20         0  pro, election, american, media, elections, par...
# 21         1  ll, want, maybe, right, shit, make, good, chin...
# 22         2  soldiers, army, year, russians, time, years, g...
# 23         3  right, fuck, good, president, time, zelensky, ...
# 24         4  european, putin, countries, deal, peace, trump...
#
#                                                 label  \
# 0      Battlefield updates (weapons, troops, visuals)
# 1              Propaganda + moral outrage / reactions
# 2            Poland border + visas + refugee movement
# 3                     Power balance + escalation talk
# 4                Invasion framing + military response
# 5       Leadership + war framing (Putin / narratives)
# 6                   War timeline + personal reactions
# 7                      Military shock + civilian harm
# 8                        Help / logistics / questions
# 9                 General reactions + humor / chatter
# 10                     Wagner / coup / power struggle
# 11            War costs + money + volunteering / work
# 12                 Combat + fighting (frontline talk)
# 13                   Reactions to footage + hot takes
# 14                    Forces + tanks + troop movement
# 15                         News cycle + media framing
# 16                      Memes / anger / online banter
# 17    Weapons + battlefield tech (tanks/missiles/air)
# 18                         War fatigue / endgame talk
# 19     Geopolitics (China/North Korea/Europe/support)
# 20            U.S. elections + partisan/media framing
# 21  Big-picture opinions + world powers (incl. China)
# 22                 Troops + casualties + war duration
# 23         Zelensky/president meeting drama reactions
# 24  Peace deal + Europe + Trump/Putin diplomacy fr...
#
#                          event
# 0                  event1_kyiv
# 1                  event1_kyiv
# 2                  event1_kyiv
# 3                  event1_kyiv
# 4                  event1_kyiv
# 5               event2_kherson
# 6               event2_kherson
# 7               event2_kherson
# 8               event2_kherson
# 9               event2_kherson
# 10            event3_stalemate
# 11            event3_stalemate
# 12            event3_stalemate
# 13            event3_stalemate
# 14            event3_stalemate
# 15       event4_trump_election
# 16       event4_trump_election
# 17       event4_trump_election
# 18       event4_trump_election
# 19       event4_trump_election
# 20  event5_white_house_meeting
# 21  event5_white_house_meeting
# 22  event5_white_house_meeting
# 23  event5_white_house_meeting
# 24  event5_white_house_meeting
